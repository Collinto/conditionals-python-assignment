# %% [markdown]
# <a href="https://colab.research.google.com/github/Collinto/conditionals-python-assignment/blob/main/string_length.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
word = input("Enter a word: ")

if len(word) > 0:
  if len(word) <= 4:
    print("Short")
  elif len(word) <= 8:
    print("Medium")
  else:
    print("Long")
else:
  print("Error: Please enter a string!")
# Out:
# Enter a word:
# Error: Please enter a string!
