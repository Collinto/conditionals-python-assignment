# %% [markdown]
# <a href="https://colab.research.google.com/github/Collinto/conditionals-python-assignment/blob/main/spacess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
stringx = input("Enter a string: ")

spaces = stringx.count(" ")

if spaces > 0:
  print("Contains space")
else:
  print("No space")
# Out:
# Enter a string: uhsjsdjk]a\
# No space
