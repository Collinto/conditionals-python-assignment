# %% [markdown]
# <a href="https://colab.research.google.com/github/Collinto/conditionals-python-assignment/blob/main/Type_of_Triangle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Determining the type of a Triangle

# %%
side1 = float(input("Enter the first side: "))
side2 = float(input("Enter the second side: "))
side3 = float(input("Enter the third side: "))

if side1 >= 1 and side2 >= 1 and side3 >= 1:
  if side1 == side2 and side2 == side3:
    print("This is an Equilateral Triangle")
  elif side1 != side2 and side2 != side3 and side1 != side3:
    print("This is a Scalene Triangle")
  else:
    print("This is isocelese")
else:
  print("Invalid length of sides ")
# Out:
# Enter the first side: 0
# Enter the second side: 45
# Enter the third side: 5
# Invalid length of sides
