# %% [markdown]
# <a href="https://colab.research.google.com/github/Collinto/conditionals-python-assignment/blob/main/num_x.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = float(input("Enter a number: "))

if num > 10 and num < 100:
  print("Great!")
else:
  print("Nah!!")
# Out:
# Enter a number: 4
# Nah!!
