# %% [markdown]
# <a href="https://colab.research.google.com/github/Collinto/conditionals-python-assignment/blob/main/string(case_blind).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## String Comparison without case sensitivity

# %%
string1= input("Enter a string: ")
string2 = input("Enter another string: ")

if string1.lower() == string2.lower():
  print("Same thing")
else:
  print("Different")
# Out:
# Enter a string: teal
# Enter another string: TEAL
# Same thing
