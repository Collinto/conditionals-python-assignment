# %% [markdown]
# <a href="https://colab.research.google.com/github/Collinto/conditionals-python-assignment/blob/main/string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
string1= input("Enter a string: ")
string2 = input("Enter another string: ")

if string1 == string2:
  print("Same thing")
else:
  print("Different")
# Out:
# Enter a string: hello
# Enter another string: Hello
# Different
