# %% [markdown]
# <a href="https://colab.research.google.com/github/Collinto/conditionals-python-assignment/blob/main/Maths_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basic Mathematical Operations

# %%
num1 = float(input("Enter first number: "))
operator = input("Enter Mathematical Operator (+, -, *, or /): ")
num2 = float(input("Enter second number: "))

match operator:
  case  "+":
    solution = num1 + num2
  case  "-":
    solution = num1 - num2
  case "*":
    solution = num1 * num2
  case  "/":
    solution = num1/num2
  case _:
    solution = "invalid operator"

print(solution)
# Out:
# Enter first number: 9
# Enter Mathematical Operator (+, -, *, or /): /
# Enter second number: 4
# 2.25
